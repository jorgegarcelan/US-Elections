# %% [markdown]
# # Datasets

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## 2008-2016 Electoral data

# %%
import pandas as pd

# Cargar los archivos CSV
data_2008_2016 = pd.read_csv("data/US_County_Level_Presidential_Results_08-16.csv")
data_2020 = pd.read_csv("data/2020_US_County_Level_Presidential_Results.csv")
data_2024 = pd.read_csv("data/2024_US_County_Level_Presidential_Results.csv")

# Convertir formato fips
data_2008_2016["county_fips"] = data_2008_2016["county_fips"].astype(str).str.zfill(5)
data_2020["county_fips"] = data_2020["county_fips"].astype(str).str.zfill(5)
data_2024["county_fips"] = data_2024["county_fips"].astype(str).str.zfill(5)

# Calcular el porcentaje de votos para cada partido en cada año (2008-2016)
data_2008_2016["per_dem_2008"] = data_2008_2016["dem_2008"] / data_2008_2016["total_2008"] * 100
data_2008_2016["per_gop_2008"] = data_2008_2016["gop_2008"] / data_2008_2016["total_2008"] * 100
data_2008_2016["per_oth_2008"] = data_2008_2016["oth_2008"] / data_2008_2016["total_2008"] * 100

data_2008_2016["per_dem_2012"] = data_2008_2016["dem_2012"] / data_2008_2016["total_2012"] * 100
data_2008_2016["per_gop_2012"] = data_2008_2016["gop_2012"] / data_2008_2016["total_2012"] * 100
data_2008_2016["per_oth_2012"] = data_2008_2016["oth_2012"] / data_2008_2016["total_2012"] * 100

data_2008_2016["per_dem_2016"] = data_2008_2016["dem_2016"] / data_2008_2016["total_2016"] * 100
data_2008_2016["per_gop_2016"] = data_2008_2016["gop_2016"] / data_2008_2016["total_2016"] * 100
data_2008_2016["per_oth_2016"] = data_2008_2016["oth_2016"] / data_2008_2016["total_2016"] * 100

# Calcular el cambio en porcentaje (delta %)
data_2008_2016["delta_per_dem_2012"] = data_2008_2016["per_dem_2012"] - data_2008_2016["per_dem_2008"]
data_2008_2016["delta_per_gop_2012"] = data_2008_2016["per_gop_2012"] - data_2008_2016["per_gop_2008"]
data_2008_2016["delta_per_oth_2012"] = data_2008_2016["per_oth_2012"] - data_2008_2016["per_oth_2008"]

data_2008_2016["delta_per_dem_2016"] = data_2008_2016["per_dem_2016"] - data_2008_2016["per_dem_2012"]
data_2008_2016["delta_per_gop_2016"] = data_2008_2016["per_gop_2016"] - data_2008_2016["per_gop_2012"]
data_2008_2016["delta_per_oth_2016"] = data_2008_2016["per_oth_2016"] - data_2008_2016["per_oth_2012"]

# Ordenar los datos por "county_fips"
data_2008_2016 = data_2008_2016.sort_values(by="county_fips")

# Preparar los datos de 2020 y 2024
data_2020 = data_2020[["county_fips", "votes_dem", "votes_gop", "total_votes", "per_dem", "per_gop"]]
data_2024 = data_2024[["county_fips", "votes_dem", "votes_gop", "total_votes", "per_dem", "per_gop"]]

# Convertir los valores de per_dem y per_gop de 0-1 a porcentaje (0-100)
data_2020["per_dem_2020"] = data_2020["per_dem"] * 100
data_2020["per_gop_2020"] = data_2020["per_gop"] * 100
data_2024["per_dem_2024"] = data_2024["per_dem"] * 100
data_2024["per_gop_2024"] = data_2024["per_gop"] * 100

# Calcular el porcentaje de otros partidos en 2020 y 2024
data_2020["per_oth_2020"] = 100 - data_2020["per_dem_2020"] - data_2020["per_gop_2020"]
data_2024["per_oth_2024"] = 100 - data_2024["per_dem_2024"] - data_2024["per_gop_2024"]

# Unir los datos de 2020 y 2024 con los de 2008-2016 usando "county_fips"
merged_data = data_2008_2016.merge(data_2020, on="county_fips", how="left")
merged_data = merged_data.merge(data_2024, on="county_fips", how="left")

# Calcular el cambio en porcentaje entre 2016 y 2020
merged_data["delta_per_dem_2020"] = merged_data["per_dem_2020"] - merged_data["per_dem_2016"]
merged_data["delta_per_gop_2020"] = merged_data["per_gop_2020"] - merged_data["per_gop_2016"]
merged_data["delta_per_oth_2020"] = merged_data["per_oth_2020"] - merged_data["per_oth_2016"]

# Calcular el cambio en porcentaje entre 2020 y 2024
merged_data["delta_per_dem_2024"] = merged_data["per_dem_2024"] - merged_data["per_dem_2020"]
merged_data["delta_per_gop_2024"] = merged_data["per_gop_2024"] - merged_data["per_gop_2020"]
merged_data["delta_per_oth_2024"] = merged_data["per_oth_2024"] - merged_data["per_oth_2020"]

# %% [markdown]
# ### Incluir cambios en los condados de Connecticut (efectivos en 2024)

# %%
# Volver a definir el diccionario de mapeo de FIPS y nombres de condados en Connecticut
fips_mapping = {
    "09001": ("09110", "Capitol Planning Region"),
    "09003": ("09120", "Greater Bridgeport Planning Region"),
    "09005": ("09130", "Lower Connecticut River Valley Planning Region"),
    "09007": ("09140", "Naugatuck Valley Planning Region"),
    "09009": ("09150", "Northeastern Connecticut Planning Region"),
    "09011": ("09160", "Northwest Hills Planning Region"),
    "09013": ("09170", "South Central Connecticut Planning Region"),
    "09015": ("09180", "Southeastern Connecticut Planning Region"),
}

# Actualizar los valores de 'county_fips' y 'county' en el dataframe
for old_fips, (new_fips, new_county) in fips_mapping.items():
    merged_data.loc[merged_data['county_fips'] == old_fips, ['county_fips', 'county_name']] = [new_fips, new_county]

# Mostrar la tabla actualizada
# data_2016[data_2016['state'] == "CT"]

# %%
# Guardar los resultados en un nuevo archivo
output_path = "data/2008_2020_delta_pct_US_County_Level_Presidential_Results.csv"
merged_data.to_csv(output_path, index=False)

print(f"Archivo guardado en: {output_path}")
merged_data
# Out:
# Archivo guardado en: data/2008_2020_delta_pct_US_County_Level_Presidential_Results.csv
#      county_fips        county_name  total_2008  dem_2008  gop_2008  oth_2008  \
# 0          01001     Autauga County       23641      6093     17403       145
# 1          01003     Baldwin County       81413     19386     61271       756
# 2          01005     Barbour County       11630      5697      5866        67
# 3          01007        Bibb County        8644      2299      6262        83
# 4          01009      Blount County       24267      3522     20389       356
# ...          ...                ...         ...       ...       ...       ...
# 3107       56037  Sweetwater County       16703      5762     10360       581
# 3108       56039       Teton County       12316      7472      4565       279
# 3109       56041       Uinta County        8383      2317      5763       303
# 3110       56043    Washakie County        4089      1042      2956        91
# 3111       56045      Weston County        3393       658      2618       117
#
#       total_2012  dem_2012  gop_2012  oth_2012  ...  per_gop_y  per_dem_2024  \
# 0          23909      6354     17366       189  ...   0.726641     26.388790
# 1          84988     18329     65772       887  ...   0.786467     20.469920
# 2          11459      5873      5539        47  ...   0.570179     42.290480
# 3           8391      2200      6131        60  ...   0.819392     17.519749
# 4          23980      2961     20741       278  ...   0.901796      9.162369
# ...          ...       ...       ...       ...  ...        ...           ...
# 3107       16750      4773     11427       550  ...   0.756895     22.517955
# 3108       11356      6211      4858       287  ...   0.316128     66.896077
# 3109        8453      1628      6613       212  ...   0.810552     17.375334
# 3110        3911       794      3013       104  ...   0.813590     17.078886
# 3111        3323       422      2821        80  ...   0.878363     10.818546
#
#       per_gop_2024  per_oth_2024  delta_per_dem_2020  delta_per_gop_2020  \
# 0        72.664065      0.947144            3.061510           -1.998987
# 1        78.646723      0.883357            2.843720           -1.180099
# 2        57.017901      0.691619           -0.872078            1.179812
# 3        81.939184      0.541067           -0.723759            1.460100
# 4        90.179619      0.658012            1.099476           -0.280322
# ...            ...           ...                 ...                 ...
# 3107     75.689541      1.792504            3.621362            0.712563
# 3108     31.612755      1.491168            7.037406           -2.617592
# 3109     81.055209      1.569457            1.995817            3.308992
# 3110     81.359021      1.562093            1.905998            2.524345
# 3111     87.836291      1.345163            1.345513            0.796187
#
#       delta_per_oth_2020  delta_per_dem_2024  delta_per_gop_2024  \
# 0              -1.062523           -0.629575            1.227263
# 1              -1.663621           -1.939110            2.475350
# 2              -0.307734           -3.497693            3.566674
# 3              -0.736341           -3.178531            3.512920
# 4              -0.819153           -0.407009            0.608067
# ...                  ...                 ...                 ...
# 3107           -4.333925           -0.508004            2.034177
# 3108           -4.419814           -0.202104            2.035866
# 3109           -5.304809            0.453402            1.327492
# 3110           -4.430343            0.852565            0.476668
# 3111           -2.141700            0.654797            0.117488
#
#       delta_per_oth_2024
# 0              -0.597688
# 1              -0.536240
# 2              -0.068982
# 3              -0.334389
# 4              -0.201057
# ...                  ...
# 3107           -1.526173
# 3108           -1.833762
# 3109           -1.780894
# 3110           -1.329233
# 3111           -0.772285
#
# [3112 rows x 51 columns]

# %% [markdown]
# ## 2016

# %%
CENSUS_YEAR = 2015
ELECTORAL_YEAR = CENSUS_YEAR + 1

# %% [markdown]
# ### Cargar características socioeconómicas y demográficas por condado

# %% [markdown]
# 📊 Los datos socioeconómicos y demográficos son de elaboración propia y han sido extraídos usando la [`API del Censo de Estados Unidos`](https://www.census.gov/data/developers/data-sets.html)

# %%
# Cargar datos
all_data = pd.read_csv(f"data/census_data_acs_{CENSUS_YEAR}.csv", header=0, sep=",")

# Renombrar columnas
all_data.rename(columns={"state": "state_code"}, inplace=True)
all_data.rename(columns={"county": "county_code"}, inplace=True)

# Filtrar los datos para excluir el estado 02 (Alaska)
all_data = all_data[all_data["state_code"] != 2]

# Filtrar los datos para excluir el estado 72 (Puerto Rico)
all_data = all_data[all_data["state_code"] != 72]

# Mostrar la tabla
all_data
# Out:
#       state_code  county_code  pop_total_2015  median_age_2015  \
# 0              1            1           55221             37.7
# 1              1            3          195121             42.2
# 2              1            5           26932             38.8
# 3              1            7           22604             38.9
# 4              1            9           57710             40.7
# ...          ...          ...             ...              ...
# 3137          56           37           44772             33.6
# 3138          56           39           22311             38.0
# 3139          56           41           20930             34.6
# 3140          56           43            8400             43.4
# 3141          56           45            7152             42.1
#
#       median_income_2015  households_median_value_2015  \
# 0                51281.0                      141300.0
# 1                50254.0                      169300.0
# 2                32964.0                       92200.0
# 3                38678.0                      102700.0
# 4                45813.0                      119800.0
# ...                  ...                           ...
# 3137             69022.0                      190900.0
# 3138             75325.0                      689000.0
# 3139             56569.0                      176700.0
# 3140             47652.0                      160800.0
# 3141             57738.0                      178200.0
#
#       households_avg_size_2015  households_total_2015  \
# 0                         2.68                  20396
# 1                         2.60                  74104
# 2                         2.61                   9222
# 3                         2.95                   7027
# 4                         2.74                  20816
# ...                        ...                    ...
# 3137                      2.64                  16679
# 3138                      2.63                   8187
# 3139                      2.76                   7502
# 3140                      2.34                   3512
# 3141                      2.27                   2986
#
#       households_median_gross_rent_2015  mean_travel_time_2015  ...  \
# 0                                 883.0                  23675  ...
# 1                                 879.0                  81184  ...
# 2                                 579.0                   8329  ...
# 3                                 651.0                   8089  ...
# 4                                 601.0                  21450  ...
# ...                                 ...                    ...  ...
# 3137                              892.0                  22118  ...
# 3138                             1113.0                  13082  ...
# 3139                              641.0                   9551  ...
# 3140                              605.0                   3583  ...
# 3141                              740.0                   3082  ...
#
#       two_more_races_rate_2015  high_school_rate_2015  bachelors_rate_2015  \
# 0                         1.57                  17.86                 8.87
# 1                         1.74                  16.53                13.52
# 2                         1.33                  18.29                 5.24
# 3                         1.37                  23.59                 4.19
# 4                         1.70                  18.75                 5.88
# ...                        ...                    ...                  ...
# 3137                      3.35                  18.69                 8.78
# 3138                      1.31                  11.71                28.52
# 3139                      3.54                  19.33                 8.67
# 3140                      3.19                  17.49                10.39
# 3141                      3.30                  19.49                 9.21
#
#       poverty_rate_2015  households_renter_rate_2015  \
# 0                 12.78                        26.08
# 1                 13.22                        28.48
# 2                 23.84                        36.41
# 3                 15.43                        24.89
# 4                 16.55                        21.10
# ...                 ...                          ...
# 3137              11.30                        29.01
# 3138               7.34                        39.50
# 3139              13.59                        26.95
# 3140              13.54                        26.25
# 3141              13.39                        21.97
#
#       households_owner_rate_2015  unemployment_rate_2015  \
# 0                          73.92                    7.64
# 1                          71.52                    7.50
# 2                          63.59                   17.65
# 3                          75.11                    8.31
# 4                          78.90                    7.67
# ...                          ...                     ...
# 3137                       70.99                    5.41
# 3138                       60.50                    2.61
# 3139                       73.05                    4.40
# 3140                       73.75                    6.80
# 3141                       78.03                    5.16
#
#       public_transport_rate_2015  no_health_insurance_rate_2015  county_fips
# 0                           0.04                           9.97         1001
# 1                           0.06                          12.81         1003
# 2                           0.13                          13.86         1005
# 3                           0.19                           8.88         1007
# 4                           0.15                          11.54         1009
# ...                          ...                            ...          ...
# 3137                        1.21                          13.40        56037
# 3138                        4.87                          16.81        56039
# 3139                        1.29                          13.93        56041
# 3140                        0.01                          16.60        56043
# 3141                        4.94                          10.74        56045
#
# [3113 rows x 37 columns]

# %% [markdown]
# ### Cargar los resultados electorales

# %% [markdown]
# 📊 Los datos electorales han sido extraídos de la siguiente fuente:
# [`US_County_Level_Election_Results_08-20.csv`](https://github.com/tonmcg/US_County_Level_Election_Results_08-20)

# %%
# Cargar datos
d1 = pd.read_csv(f"data/{ELECTORAL_YEAR}_US_County_Level_Presidential_Results.csv")

# Crear nueva columna 'votes_others'
d1['votes_others'] = d1['total_votes'] - (d1['votes_gop'] + d1['votes_dem'])

# Crear nueva columna 'perc votes_others'
d1['perc votes_others'] = 1 - d1['per_dem'] - d1['per_gop']

# Quedarse con columnas específicas
d1 = d1[['state_name', 'county_fips', 'county_name', 'votes_gop', 'votes_dem', 'total_votes', 'votes_others', 'perc votes_others', 'per_dem', 'per_gop']]

# Renombrar columnas
# d1.columns = ["state", "fips", "county", f"Trump_{ELECTORAL_YEAR}", f"Biden_{ELECTORAL_YEAR}", f"Total_{ELECTORAL_YEAR}", f"Other_{ELECTORAL_YEAR}", f"Perc_Other_{ELECTORAL_YEAR}", f"Perc_Biden_{ELECTORAL_YEAR}", f"Perc_Trump_{ELECTORAL_YEAR}"]
d1.rename(columns={"state_name": "state"}, inplace=True)
d1.rename(columns={"county_name": "county"}, inplace=True)
d1.rename(columns={"votes_gop": f"votes_gop_{ELECTORAL_YEAR}"}, inplace=True)
d1.rename(columns={"votes_dem": f"votes_dem_{ELECTORAL_YEAR}"}, inplace=True)
d1.rename(columns={"total_votes": f"total_votes_{ELECTORAL_YEAR}"}, inplace=True)
d1.rename(columns={"votes_others": f"votes_others_{ELECTORAL_YEAR}"}, inplace=True)
d1.rename(columns={"perc votes_others": f"per_votes_others_{ELECTORAL_YEAR}"}, inplace=True)
d1.rename(columns={"per_dem": f"per_dem_{ELECTORAL_YEAR}"}, inplace=True)
d1.rename(columns={"per_gop": f"per_gop_{ELECTORAL_YEAR}"}, inplace=True)

# Mostrar la tabla
d1
# Out:
#      state  county_fips             county  votes_gop_2016  votes_dem_2016  \
# 0       AK         2013             Alaska        130413.0         93003.0
# 1       AK         2016             Alaska        130413.0         93003.0
# 2       AK         2020             Alaska        130413.0         93003.0
# 3       AK         2050             Alaska        130413.0         93003.0
# 4       AK         2060             Alaska        130413.0         93003.0
# ...    ...          ...                ...             ...             ...
# 3136    WY        56037  Sweetwater County         12153.0          3233.0
# 3137    WY        56039       Teton County          3920.0          7313.0
# 3138    WY        56041       Uinta County          6154.0          1202.0
# 3139    WY        56043    Washakie County          2911.0           532.0
# 3140    WY        56045      Weston County          2898.0           294.0
#
#       total_votes_2016  votes_others_2016  per_votes_others_2016  \
# 0             246588.0            23172.0               0.093971
# 1             246588.0            23172.0               0.093971
# 2             246588.0            23172.0               0.093971
# 3             246588.0            23172.0               0.093971
# 4             246588.0            23172.0               0.093971
# ...                ...                ...                    ...
# 3136           16661.0             1275.0               0.076526
# 3137           12176.0              943.0               0.077447
# 3138            8053.0              697.0               0.086552
# 3139            3715.0              272.0               0.073217
# 3140            3334.0              142.0               0.042591
#
#       per_dem_2016  per_gop_2016
# 0         0.377159      0.528870
# 1         0.377159      0.528870
# 2         0.377159      0.528870
# 3         0.377159      0.528870
# 4         0.377159      0.528870
# ...            ...           ...
# 3136      0.194046      0.729428
# 3137      0.600608      0.321945
# 3138      0.149261      0.764187
# 3139      0.143203      0.783580
# 3140      0.088182      0.869226
#
# [3141 rows x 10 columns]

# %% [markdown]
# ### Unir los dos datasets

# %%
# Unir los dos datasets
data_2016 = pd.merge(d1, all_data, how='right', on=["county_fips"])

# Código FIPS tiene que tener 5 dígitos
data_2016['county_fips'] = data_2016['county_fips'].astype(str).str.zfill(5)

# Mostrar la tabla
data_2016
# Out:
#      state county_fips             county  votes_gop_2016  votes_dem_2016  \
# 0       AL       01001     Autauga County         18110.0          5908.0
# 1       AL       01003     Baldwin County         72780.0         18409.0
# 2       AL       01005     Barbour County          5431.0          4848.0
# 3       AL       01007        Bibb County          6733.0          1874.0
# 4       AL       01009      Blount County         22808.0          2150.0
# ...    ...         ...                ...             ...             ...
# 3108    WY       56037  Sweetwater County         12153.0          3233.0
# 3109    WY       56039       Teton County          3920.0          7313.0
# 3110    WY       56041       Uinta County          6154.0          1202.0
# 3111    WY       56043    Washakie County          2911.0           532.0
# 3112    WY       56045      Weston County          2898.0           294.0
#
#       total_votes_2016  votes_others_2016  per_votes_others_2016  \
# 0              24661.0              643.0               0.026074
# 1              94090.0             2901.0               0.030832
# 2              10390.0              111.0               0.010683
# 3               8748.0              141.0               0.016118
# 4              25384.0              426.0               0.016782
# ...                ...                ...                    ...
# 3108           16661.0             1275.0               0.076526
# 3109           12176.0              943.0               0.077447
# 3110            8053.0              697.0               0.086552
# 3111            3715.0              272.0               0.073217
# 3112            3334.0              142.0               0.042591
#
#       per_dem_2016  per_gop_2016  ...  hispanic_rate_2015  \
# 0         0.239569      0.734358  ...                2.61
# 1         0.195653      0.773515  ...                4.50
# 2         0.466603      0.522714  ...                4.61
# 3         0.214220      0.769662  ...                2.22
# 4         0.084699      0.898519  ...                8.63
# ...            ...           ...  ...                 ...
# 3108      0.194046      0.729428  ...               15.76
# 3109      0.600608      0.321945  ...               15.14
# 3110      0.149261      0.764187  ...                8.88
# 3111      0.143203      0.783580  ...               13.99
# 3112      0.088182      0.869226  ...                3.27
#
#       two_more_races_rate_2015  high_school_rate_2015  bachelors_rate_2015  \
# 0                         1.57                  17.86                 8.87
# 1                         1.74                  16.53                13.52
# 2                         1.33                  18.29                 5.24
# 3                         1.37                  23.59                 4.19
# 4                         1.70                  18.75                 5.88
# ...                        ...                    ...                  ...
# 3108                      3.35                  18.69                 8.78
# 3109                      1.31                  11.71                28.52
# 3110                      3.54                  19.33                 8.67
# 3111                      3.19                  17.49                10.39
# 3112                      3.30                  19.49                 9.21
#
#       poverty_rate_2015  households_renter_rate_2015  \
# 0                 12.78                        26.08
# 1                 13.22                        28.48
# 2                 23.84                        36.41
# 3                 15.43                        24.89
# 4                 16.55                        21.10
# ...                 ...                          ...
# 3108              11.30                        29.01
# 3109               7.34                        39.50
# 3110              13.59                        26.95
# 3111              13.54                        26.25
# 3112              13.39                        21.97
#
#       households_owner_rate_2015  unemployment_rate_2015  \
# 0                          73.92                    7.64
# 1                          71.52                    7.50
# 2                          63.59                   17.65
# 3                          75.11                    8.31
# 4                          78.90                    7.67
# ...                          ...                     ...
# 3108                       70.99                    5.41
# 3109                       60.50                    2.61
# 3110                       73.05                    4.40
# 3111                       73.75                    6.80
# 3112                       78.03                    5.16
#
#       public_transport_rate_2015  no_health_insurance_rate_2015
# 0                           0.04                           9.97
# 1                           0.06                          12.81
# 2                           0.13                          13.86
# 3                           0.19                           8.88
# 4                           0.15                          11.54
# ...                          ...                            ...
# 3108                        1.21                          13.40
# 3109                        4.87                          16.81
# 3110                        1.29                          13.93
# 3111                        0.01                          16.60
# 3112                        4.94                          10.74
#
# [3113 rows x 46 columns]

# %% [markdown]
# ### Incluir cambios en los condados de Connecticut (efectivos en 2024)

# %%
# Volver a definir el diccionario de mapeo de FIPS y nombres de condados en Connecticut
fips_mapping = {
    "09001": ("09110", "Capitol Planning Region"),
    "09003": ("09120", "Greater Bridgeport Planning Region"),
    "09005": ("09130", "Lower Connecticut River Valley Planning Region"),
    "09007": ("09140", "Naugatuck Valley Planning Region"),
    "09009": ("09150", "Northeastern Connecticut Planning Region"),
    "09011": ("09160", "Northwest Hills Planning Region"),
    "09013": ("09170", "South Central Connecticut Planning Region"),
    "09015": ("09180", "Southeastern Connecticut Planning Region"),
}

# Actualizar los valores de 'county_fips' y 'county' en el dataframe
for old_fips, (new_fips, new_county) in fips_mapping.items():
    data_2016.loc[data_2016['county_fips'] == old_fips, ['county_fips', 'county']] = [new_fips, new_county]

# Mostrar la tabla actualizada
# data_2016[data_2016['state'] == "CT"]

# %% [markdown]
# ### Calcular el ganador en cada condado

# %% [markdown]
# <div style="border-left: 4px solid #0074cc; background-color: #e6f4ff; padding: 10px;">
#     <strong>Nota:</strong> Por simplicidad, para calcular el ganador en cada condado asumimos que si hay un empate el ganador es Biden. En cualquier otro caso, el ganador será el que haya obtenido más del 50% de los votos.
# </div>

# %%
data_2016[f'winner_{ELECTORAL_YEAR}'] = data_2016[f'per_dem_{ELECTORAL_YEAR}'].apply(lambda x: "dem" if x >= 0.50 else "gop")

# %% [markdown]
# ### Valores ausentes (NAs)

# %%
missing_fips_2016 = data_2016[data_2016.isna().any(axis=1)]['county_fips'].tolist()
missing_fips_2016
# Out:
# ['15005', '32029', '46102', '48261', '48301']

# %%
data_2016 = data_2016.dropna(how="any")
data_2016[data_2016.isna().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [state, county_fips, county, votes_gop_2016, votes_dem_2016, total_votes_2016, votes_others_2016, per_votes_others_2016, per_dem_2016, per_gop_2016, state_code, county_code, pop_total_2015, median_age_2015, median_income_2015, households_median_value_2015, households_avg_size_2015, households_total_2015, households_median_gross_rent_2015, mean_travel_time_2015, pop_total_male_rate_2015, pop_total_female_rate_2015, pop_18_39_male_rate_2015, pop_18_39_female_rate_2015, pop_40_64_male_rate_2015, pop_40_64_female_rate_2015, pop_over_65_male_rate_2015, pop_over_65_female_rate_2015, veterans_rate_2015, inmigrants_rate_2015, white_rate_2015, black_rate_2015, native_rate_2015, asian_rate_2015, pacific_rate_2015, other_rate_2015, hispanic_rate_2015, two_more_races_rate_2015, high_school_rate_2015, bachelors_rate_2015, poverty_rate_2015, households_renter_rate_2015, households_owner_rate_2015, unemployment_rate_2015, public_transport_rate_2015, no_health_insurance_rate_2015, winner_2016]
# Index: []
#
# [0 rows x 47 columns]

# %% [markdown]
# ### Añadir columnas de delta (2016 - 2012)

# %%
# Seleccionar las columnas de delta de 2016
delta_cols_2016 = ["county_fips", "delta_per_dem_2016", "delta_per_gop_2016", "delta_per_oth_2016"]

# Unir los datos por "county_fips"
data_2016 = data_2016.merge(merged_data[delta_cols_2016], on="county_fips", how="left")

# Verificar los valores NaN en las columnas añadidas
missing_values = data_2016[["delta_per_dem_2016", "delta_per_gop_2016", "delta_per_oth_2016"]].isna().sum()

print(missing_values)
# Out:
# delta_per_dem_2016    0
# delta_per_gop_2016    0
# delta_per_oth_2016    0
# dtype: int64

# %% [markdown]
# ### Quitar "_2016" del nombre de las variables

# %%
# Renombrar columnas para quitar el sufijo "_{CENSUS_YEAR}" o "_{ELECTORAL_YEAR}"
data_2016.columns = [col.replace(f'_{CENSUS_YEAR}', '').replace(f'_{ELECTORAL_YEAR}', '') for col in data_2016.columns]

# %%
data_2016
# Out:
#      state county_fips             county  votes_gop  votes_dem  total_votes  \
# 0       AL       01001     Autauga County    18110.0     5908.0      24661.0
# 1       AL       01003     Baldwin County    72780.0    18409.0      94090.0
# 2       AL       01005     Barbour County     5431.0     4848.0      10390.0
# 3       AL       01007        Bibb County     6733.0     1874.0       8748.0
# 4       AL       01009      Blount County    22808.0     2150.0      25384.0
# ...    ...         ...                ...        ...        ...          ...
# 3103    WY       56037  Sweetwater County    12153.0     3233.0      16661.0
# 3104    WY       56039       Teton County     3920.0     7313.0      12176.0
# 3105    WY       56041       Uinta County     6154.0     1202.0       8053.0
# 3106    WY       56043    Washakie County     2911.0      532.0       3715.0
# 3107    WY       56045      Weston County     2898.0      294.0       3334.0
#
#       votes_others  per_votes_others   per_dem   per_gop  ...  poverty_rate  \
# 0            643.0          0.026074  0.239569  0.734358  ...         12.78
# 1           2901.0          0.030832  0.195653  0.773515  ...         13.22
# 2            111.0          0.010683  0.466603  0.522714  ...         23.84
# 3            141.0          0.016118  0.214220  0.769662  ...         15.43
# 4            426.0          0.016782  0.084699  0.898519  ...         16.55
# ...            ...               ...       ...       ...  ...           ...
# 3103        1275.0          0.076526  0.194046  0.729428  ...         11.30
# 3104         943.0          0.077447  0.600608  0.321945  ...          7.34
# 3105         697.0          0.086552  0.149261  0.764187  ...         13.59
# 3106         272.0          0.073217  0.143203  0.783580  ...         13.54
# 3107         142.0          0.042591  0.088182  0.869226  ...         13.39
#
#       households_renter_rate  households_owner_rate  unemployment_rate  \
# 0                      26.08                  73.92               7.64
# 1                      28.48                  71.52               7.50
# 2                      36.41                  63.59              17.65
# 3                      24.89                  75.11               8.31
# 4                      21.10                  78.90               7.67
# ...                      ...                    ...                ...
# 3103                   29.01                  70.99               5.41
# 3104                   39.50                  60.50               2.61
# 3105                   26.95                  73.05               4.40
# 3106                   26.25                  73.75               6.80
# 3107                   21.97                  78.03               5.16
#
#       public_transport_rate  no_health_insurance_rate  winner  delta_per_dem  \
# 0                      0.04                      9.97     gop      -2.618911
# 1                      0.06                     12.81     gop      -2.001264
# 2                      0.13                     13.86     gop      -4.592041
# 3                      0.19                      8.88     gop      -4.796528
# 4                      0.15                     11.54     gop      -3.877888
# ...                     ...                       ...     ...            ...
# 3103                   1.21                     13.40     gop      -9.090925
# 3104                   4.87                     16.81     dem       5.367221
# 3105                   1.29                     13.93     gop      -4.333320
# 3106                   0.01                     16.60     gop      -5.981390
# 3107                   4.94                     10.74     gop      -3.881132
#
#       delta_per_gop  delta_per_oth
# 0          0.802053       1.816858
# 1         -0.038277       2.039541
# 2          3.933864       0.658177
# 3          3.899783       0.896745
# 4          3.358964       0.518923
# ...             ...            ...
# 3103       4.721905       4.369020
# 3104     -10.584667       5.217445
# 3105      -1.813854       6.147174
# 3106       1.318888       4.662502
# 3107       2.029447       1.851685
#
# [3108 rows x 50 columns]

# %% [markdown]
# ## 2020

# %%
CENSUS_YEAR = 2019
ELECTORAL_YEAR = CENSUS_YEAR + 1

# %% [markdown]
# ### Cargar características socioeconómicas y demográficas por condado

# %% [markdown]
# 📊 Los datos socioeconómicos y demográficos son de elaboración propia y han sido extraídos usando la [`API del Censo de Estados Unidos`](https://www.census.gov/data/developers/data-sets.html)

# %%
# Cargar datos
all_data = pd.read_csv(f"data/census_data_acs_{CENSUS_YEAR}.csv", header=0, sep=",")

# Renombrar columnas
all_data.rename(columns={"state": "state_code"}, inplace=True)
all_data.rename(columns={"county": "county_code"}, inplace=True)

# Filtrar los datos para excluir el estado 02 (Alaska)
all_data = all_data[all_data["state_code"] != 2]

# Filtrar los datos para excluir el estado 72 (Puerto Rico)
all_data = all_data[all_data["state_code"] != 72]

# Mostrar la tabla
all_data
# Out:
#       state_code  county_code  pop_total_2019  median_age_2019  \
# 0              1            1           55380             38.2
# 1              1            3          212830             43.0
# 2              1            5           25361             40.4
# 3              1            7           22493             40.9
# 4              1            9           57681             40.7
# ...          ...          ...             ...              ...
# 3137          56           37           43521             35.3
# 3138          56           39           23280             39.3
# 3139          56           41           20479             35.8
# 3140          56           43            8027             42.9
# 3141          56           45            7049             43.1
#
#       median_income_2019  households_median_value_2019  \
# 0                  58731                        154500
# 1                  58320                        197900
# 2                  32525                         90700
# 3                  47542                         92800
# 4                  49358                        127800
# ...                  ...                           ...
# 3137               74843                        205600
# 3138               84678                        866600
# 3139               63403                        175000
# 3140               54158                        165800
# 3141               57031                        166300
#
#       households_avg_size_2019  households_total_2019  \
# 0                         2.56                  21397
# 1                         2.59                  80930
# 2                         2.41                   9345
# 3                         2.99                   6891
# 4                         2.74                  20847
# ...                        ...                    ...
# 3137                      2.77                  15523
# 3138                      2.47                   9019
# 3139                      2.66                   7597
# 3140                      2.34                   3365
# 3141                      2.32                   2891
#
#       households_median_gross_rent_2019  mean_travel_time_2019  ...  \
# 0                                   986                  23796  ...
# 1                                  1020                  87084  ...
# 2                                   576                   8108  ...
# 3                                   734                   7910  ...
# 4                                   667                  21361  ...
# ...                                 ...                    ...  ...
# 3137                                861                  20717  ...
# 3138                               1376                  13079  ...
# 3139                                698                   8960  ...
# 3140                                640                   3512  ...
# 3141                                767                   2941  ...
#
#       two_more_races_rate_2019  high_school_rate_2019  bachelors_rate_2019  \
# 0                         2.16                  19.21                10.87
# 1                         1.69                  15.90                14.94
# 2                         1.20                  20.10                 5.39
# 3                         0.63                  25.35                 4.64
# 4                         1.59                  18.57                 5.95
# ...                        ...                    ...                  ...
# 3137                      2.27                  16.58                 9.50
# 3138                      0.65                  10.19                28.98
# 3139                      3.55                  21.49                 7.00
# 3140                      3.79                  15.72                10.64
# 3141                      1.28                  22.58                 9.68
#
#       poverty_rate_2019  households_renter_rate_2019  \
# 0                 15.06                        26.71
# 1                 10.20                        24.75
# 2                 27.11                        39.10
# 3                 16.63                        25.58
# 4                 13.42                        21.22
# ...                 ...                          ...
# 3137              11.31                        23.78
# 3138               6.13                        39.59
# 3139              11.22                        22.94
# 3140              10.28                        23.51
# 3141              13.78                        16.98
#
#       households_owner_rate_2019  unemployment_rate_2019  \
# 0                          73.29                    3.68
# 1                          75.25                    4.26
# 2                          60.90                    9.17
# 3                          74.42                    7.28
# 4                          78.78                    3.36
# ...                          ...                     ...
# 3137                       76.22                    6.09
# 3138                       60.41                    1.08
# 3139                       77.06                    6.28
# 3140                       76.49                    3.92
# 3141                       83.02                    4.14
#
#       public_transport_rate_2019  no_health_insurance_rate_2019  county_fips
# 0                           0.29                           6.96         1001
# 1                           0.02                           8.78         1003
# 2                           0.11                          10.03         1005
# 3                           0.00                           9.79         1007
# 4                           0.05                          10.68         1009
# ...                          ...                            ...          ...
# 3137                        1.41                          11.18        56037
# 3138                        2.12                          12.71        56039
# 3139                        1.47                          11.09        56041
# 3140                        0.00                          14.73        56043
# 3141                        4.26                          11.26        56045
#
# [3113 rows x 37 columns]

# %% [markdown]
# ### Cargar los resultados electorales

# %% [markdown]
# 📊 Los datos electorales han sido extraídos de la siguiente fuente:
# [`US_County_Level_Election_Results_08-20.csv`](https://github.com/tonmcg/US_County_Level_Election_Results_08-20)

# %%
# Cargar datos
d1 = pd.read_csv(f"data/{ELECTORAL_YEAR}_US_County_Level_Presidential_Results.csv")

# Crear nueva columna 'votes_others'
d1['votes_others'] = d1['total_votes'] - (d1['votes_gop'] + d1['votes_dem'])

# Crear nueva columna 'perc votes_others'
d1['perc votes_others'] = 1 - d1['per_dem'] - d1['per_gop']

# Quedarse con columnas específicas
d1 = d1[['state_name', 'county_fips', 'county_name', 'votes_gop', 'votes_dem', 'total_votes', 'votes_others', 'perc votes_others', 'per_dem', 'per_gop']]

# Renombrar columnas
# d1.columns = ["state", "fips", "county", f"Trump_{ELECTORAL_YEAR}", f"Biden_{ELECTORAL_YEAR}", f"Total_{ELECTORAL_YEAR}", f"Other_{ELECTORAL_YEAR}", f"Perc_Other_{ELECTORAL_YEAR}", f"Perc_Biden_{ELECTORAL_YEAR}", f"Perc_Trump_{ELECTORAL_YEAR}"]
d1.rename(columns={"state_name": "state"}, inplace=True)
d1.rename(columns={"county_name": "county"}, inplace=True)
d1.rename(columns={"votes_gop": f"votes_gop_{ELECTORAL_YEAR}"}, inplace=True)
d1.rename(columns={"votes_dem": f"votes_dem_{ELECTORAL_YEAR}"}, inplace=True)
d1.rename(columns={"total_votes": f"total_votes_{ELECTORAL_YEAR}"}, inplace=True)
d1.rename(columns={"votes_others": f"votes_others_{ELECTORAL_YEAR}"}, inplace=True)
d1.rename(columns={"perc votes_others": f"per_votes_others_{ELECTORAL_YEAR}"}, inplace=True)
d1.rename(columns={"per_dem": f"per_dem_{ELECTORAL_YEAR}"}, inplace=True)
d1.rename(columns={"per_gop": f"per_gop_{ELECTORAL_YEAR}"}, inplace=True)

# Mostrar la tabla
d1
# Out:
#         state  county_fips             county  votes_gop_2020  votes_dem_2020  \
# 0     Alabama         1001     Autauga County           19838            7503
# 1     Alabama         1003     Baldwin County           83544           24578
# 2     Alabama         1005     Barbour County            5622            4816
# 3     Alabama         1007        Bibb County            7525            1986
# 4     Alabama         1009      Blount County           24711            2640
# ...       ...          ...                ...             ...             ...
# 3147  Wyoming        56037  Sweetwater County           12229            3823
# 3148  Wyoming        56039       Teton County            4341            9848
# 3149  Wyoming        56041       Uinta County            7496            1591
# 3150  Wyoming        56043    Washakie County            3245             651
# 3151  Wyoming        56045      Weston County            3107             360
#
#       total_votes_2020  votes_others_2020  per_votes_others_2020  \
# 0                27770                429               0.015448
# 1               109679               1557               0.014196
# 2                10518                 80               0.007606
# 3                 9595                 84               0.008755
# 4                27588                237               0.008591
# ...                ...                ...                    ...
# 3147             16603                551               0.033187
# 3148             14677                488               0.033249
# 3149              9402                315               0.033504
# 3150              4012                116               0.028913
# 3151              3542                 75               0.021174
#
#       per_dem_2020  per_gop_2020
# 0         0.270184      0.714368
# 1         0.224090      0.761714
# 2         0.457882      0.534512
# 3         0.206983      0.784263
# 4         0.095694      0.895716
# ...            ...           ...
# 3147      0.230260      0.736554
# 3148      0.670982      0.295769
# 3149      0.169219      0.797277
# 3150      0.162263      0.808824
# 3151      0.101637      0.877188
#
# [3152 rows x 10 columns]

# %% [markdown]
# ### Unir los dos datasets

# %%
# Unir los dos datasets
data_2020 = pd.merge(d1, all_data, how='right', on=["county_fips"])

# Código FIPS tiene que tener 5 dígitos
data_2020['county_fips'] = data_2020['county_fips'].astype(str).str.zfill(5)

# Mostrar la tabla
data_2020
# Out:
#         state county_fips             county  votes_gop_2020  votes_dem_2020  \
# 0     Alabama       01001     Autauga County         19838.0          7503.0
# 1     Alabama       01003     Baldwin County         83544.0         24578.0
# 2     Alabama       01005     Barbour County          5622.0          4816.0
# 3     Alabama       01007        Bibb County          7525.0          1986.0
# 4     Alabama       01009      Blount County         24711.0          2640.0
# ...       ...         ...                ...             ...             ...
# 3108  Wyoming       56037  Sweetwater County         12229.0          3823.0
# 3109  Wyoming       56039       Teton County          4341.0          9848.0
# 3110  Wyoming       56041       Uinta County          7496.0          1591.0
# 3111  Wyoming       56043    Washakie County          3245.0           651.0
# 3112  Wyoming       56045      Weston County          3107.0           360.0
#
#       total_votes_2020  votes_others_2020  per_votes_others_2020  \
# 0              27770.0              429.0               0.015448
# 1             109679.0             1557.0               0.014196
# 2              10518.0               80.0               0.007606
# 3               9595.0               84.0               0.008755
# 4              27588.0              237.0               0.008591
# ...                ...                ...                    ...
# 3108           16603.0              551.0               0.033187
# 3109           14677.0              488.0               0.033249
# 3110            9402.0              315.0               0.033504
# 3111            4012.0              116.0               0.028913
# 3112            3542.0               75.0               0.021174
#
#       per_dem_2020  per_gop_2020  ...  hispanic_rate_2019  \
# 0         0.270184      0.714368  ...                2.83
# 1         0.224090      0.761714  ...                4.56
# 2         0.457882      0.534512  ...                4.36
# 3         0.206983      0.784263  ...                2.57
# 4         0.095694      0.895716  ...                9.26
# ...            ...           ...  ...                 ...
# 3108      0.230260      0.736554  ...               15.88
# 3109      0.670982      0.295769  ...               15.03
# 3110      0.169219      0.797277  ...                9.13
# 3111      0.162263      0.808824  ...               14.23
# 3112      0.101637      0.877188  ...                1.08
#
#       two_more_races_rate_2019  high_school_rate_2019  bachelors_rate_2019  \
# 0                         2.16                  19.21                10.87
# 1                         1.69                  15.90                14.94
# 2                         1.20                  20.10                 5.39
# 3                         0.63                  25.35                 4.64
# 4                         1.59                  18.57                 5.95
# ...                        ...                    ...                  ...
# 3108                      2.27                  16.58                 9.50
# 3109                      0.65                  10.19                28.98
# 3110                      3.55                  21.49                 7.00
# 3111                      3.79                  15.72                10.64
# 3112                      1.28                  22.58                 9.68
#
#       poverty_rate_2019  households_renter_rate_2019  \
# 0                 15.06                        26.71
# 1                 10.20                        24.75
# 2                 27.11                        39.10
# 3                 16.63                        25.58
# 4                 13.42                        21.22
# ...                 ...                          ...
# 3108              11.31                        23.78
# 3109               6.13                        39.59
# 3110              11.22                        22.94
# 3111              10.28                        23.51
# 3112              13.78                        16.98
#
#       households_owner_rate_2019  unemployment_rate_2019  \
# 0                          73.29                    3.68
# 1                          75.25                    4.26
# 2                          60.90                    9.17
# 3                          74.42                    7.28
# 4                          78.78                    3.36
# ...                          ...                     ...
# 3108                       76.22                    6.09
# 3109                       60.41                    1.08
# 3110                       77.06                    6.28
# 3111                       76.49                    3.92
# 3112                       83.02                    4.14
#
#       public_transport_rate_2019  no_health_insurance_rate_2019
# 0                           0.29                           6.96
# 1                           0.02                           8.78
# 2                           0.11                          10.03
# 3                           0.00                           9.79
# 4                           0.05                          10.68
# ...                          ...                            ...
# 3108                        1.41                          11.18
# 3109                        2.12                          12.71
# 3110                        1.47                          11.09
# 3111                        0.00                          14.73
# 3112                        4.26                          11.26
#
# [3113 rows x 46 columns]

# %% [markdown]
# ### Incluir cambios en los condados de Connecticut (efectivos en 2024)
# https://appliedgeographic.com/2023/04/changing-of-the-counties/

# %%
# Volver a definir el diccionario de mapeo de FIPS y nombres de condados en Connecticut
fips_mapping = {
    "09001": ("09110", "Capitol Planning Region"),
    "09003": ("09120", "Greater Bridgeport Planning Region"),
    "09005": ("09130", "Lower Connecticut River Valley Planning Region"),
    "09007": ("09140", "Naugatuck Valley Planning Region"),
    "09009": ("09150", "Northeastern Connecticut Planning Region"),
    "09011": ("09160", "Northwest Hills Planning Region"),
    "09013": ("09170", "South Central Connecticut Planning Region"),
    "09015": ("09180", "Southeastern Connecticut Planning Region"),
}

# Actualizar los valores de 'county_fips' y 'county' en el dataframe
for old_fips, (new_fips, new_county) in fips_mapping.items():
    data_2020.loc[data_2020['county_fips'] == old_fips, ['county_fips', 'county']] = [new_fips, new_county]

# Mostrar la tabla actualizada
data_2020[data_2020['state'] == "Connecticut"]
# Out:
#            state county_fips                                          county  \
# 279  Connecticut       09110                         Capitol Planning Region
# 280  Connecticut       09120              Greater Bridgeport Planning Region
# 281  Connecticut       09130  Lower Connecticut River Valley Planning Region
# 282  Connecticut       09140                Naugatuck Valley Planning Region
# 283  Connecticut       09150        Northeastern Connecticut Planning Region
# 284  Connecticut       09160                 Northwest Hills Planning Region
# 285  Connecticut       09170       South Central Connecticut Planning Region
# 286  Connecticut       09180        Southeastern Connecticut Planning Region
#
#      votes_gop_2020  votes_dem_2020  total_votes_2020  votes_others_2020  \
# 279        169039.0        297505.0          472990.0             6446.0
# 280        159024.0        283368.0          449336.0             6944.0
# 281         55601.0         50164.0          107544.0             1779.0
# 282         40665.0         56848.0           99203.0             1690.0
# 283        169892.0        242629.0          417980.0             5459.0
# 284         57110.0         79459.0          139604.0             3035.0
# 285         34819.0         44006.0           80546.0             1721.0
# 286         29141.0         26701.0           57077.0             1235.0
#
#      per_votes_others_2020  per_dem_2020  per_gop_2020  ...  \
# 279               0.013628      0.628988      0.357384  ...
# 280               0.015454      0.630637      0.353909  ...
# 281               0.016542      0.466451      0.517007  ...
# 282               0.017036      0.573047      0.409917  ...
# 283               0.013060      0.580480      0.406460  ...
# 284               0.021740      0.569174      0.409086  ...
# 285               0.021367      0.546346      0.432287  ...
# 286               0.021637      0.467807      0.510556  ...
#
#      hispanic_rate_2019  two_more_races_rate_2019  high_school_rate_2019  \
# 279               19.70                      3.15                  13.15
# 280               18.03                      3.57                  16.12
# 281                6.28                      2.18                  19.33
# 282                6.19                      2.06                  17.03
# 283               18.11                      3.25                  19.10
# 284               10.55                      5.34                  17.91
# 285                5.52                      2.37                  14.92
# 286               11.80                      3.70                  19.49
#
#      bachelors_rate_2019  poverty_rate_2019  households_renter_rate_2019  \
# 279                18.24               8.72                        32.95
# 280                14.88              10.54                        35.89
# 281                15.18               6.82                        23.51
# 282                17.27               6.71                        26.48
# 283                12.96              11.38                        38.15
# 284                12.90               8.99                        33.63
# 285                15.06               6.62                        28.24
# 286                10.33              10.88                        31.03
#
#      households_owner_rate_2019  unemployment_rate_2019  \
# 279                       67.05                    6.56
# 280                       64.11                    5.84
# 281                       76.49                    4.98
# 282                       73.52                    4.65
# 283                       61.85                    6.44
# 284                       66.37                    5.93
# 285                       71.76                    4.89
# 286                       68.97                    5.54
#
#      public_transport_rate_2019  no_health_insurance_rate_2019
# 279                        4.98                           8.35
# 280                        1.57                           4.00
# 281                        0.74                           3.84
# 282                        0.79                           3.17
# 283                        1.88                           4.94
# 284                        0.74                           3.84
# 285                        0.95                           2.52
# 286                        0.29                           4.06
#
# [8 rows x 46 columns]

# %% [markdown]
# ### Calcular el ganador en cada condado

# %% [markdown]
# <div style="border-left: 4px solid #0074cc; background-color: #e6f4ff; padding: 10px;">
#     <strong>Nota:</strong> Por simplicidad, para calcular el ganador en cada condado asumimos que si hay un empate el ganador es Biden. En cualquier otro caso, el ganador será el que haya obtenido más del 50% de los votos.
# </div>

# %%
data_2020[f'winner_{ELECTORAL_YEAR}'] = data_2020[f'per_dem_{ELECTORAL_YEAR}'].apply(lambda x: "dem" if x >= 0.50 else "gop")

# %% [markdown]
# ### Valores ausentes (NAs)

# %%
missing_fips_2020 = data_2020[data_2020.isna().any(axis=1)]['county_fips'].tolist()
missing_fips_2020
# Out:
# ['15005']

# %%
data_2020 = data_2020.dropna(how="any")
data_2020[data_2020.isna().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [state, county_fips, county, votes_gop_2020, votes_dem_2020, total_votes_2020, votes_others_2020, per_votes_others_2020, per_dem_2020, per_gop_2020, state_code, county_code, pop_total_2019, median_age_2019, median_income_2019, households_median_value_2019, households_avg_size_2019, households_total_2019, households_median_gross_rent_2019, mean_travel_time_2019, pop_total_male_rate_2019, pop_total_female_rate_2019, pop_18_39_male_rate_2019, pop_18_39_female_rate_2019, pop_40_64_male_rate_2019, pop_40_64_female_rate_2019, pop_over_65_male_rate_2019, pop_over_65_female_rate_2019, veterans_rate_2019, inmigrants_rate_2019, white_rate_2019, black_rate_2019, native_rate_2019, asian_rate_2019, pacific_rate_2019, other_rate_2019, hispanic_rate_2019, two_more_races_rate_2019, high_school_rate_2019, bachelors_rate_2019, poverty_rate_2019, households_renter_rate_2019, households_owner_rate_2019, unemployment_rate_2019, public_transport_rate_2019, no_health_insurance_rate_2019, winner_2020]
# Index: []
#
# [0 rows x 47 columns]

# %% [markdown]
# ### Añadir columnas de delta (2020 - 2016)

# %%
# Seleccionar las columnas de delta de 2020
delta_cols_2020 = ["county_fips", "delta_per_dem_2020", "delta_per_gop_2020", "delta_per_oth_2020"]

# Unir los datos por "county_fips"
data_2020 = data_2020.merge(merged_data[delta_cols_2020], on="county_fips", how="left")

# %%
# Identificar los county_fips con valores NaN
missing_fips = data_2020[data_2020["delta_per_dem_2020"].isna()]["county_fips"].iloc[0]
print(missing_fips)

missing_fips_2020.append(missing_fips)
print(missing_fips_2020)
# Out:
# 46102
# ['15005', '46102']

# %% [markdown]
# ### Quitar "_2020" del nombre de las variables

# %%
# Renombrar columnas para quitar el sufijo "_{CENSUS_YEAR}" o "_{ELECTORAL_YEAR}"
data_2020.columns = [col.replace(f'_{CENSUS_YEAR}', '').replace(f'_{ELECTORAL_YEAR}', '') for col in data_2020.columns]

# %% [markdown]
# ## 2024

# %%
CENSUS_YEAR = 2023
ELECTORAL_YEAR = CENSUS_YEAR + 1

# %% [markdown]
# ### Cargar características socioeconómicas y demográficas por condado

# %% [markdown]
# 📊 Los datos socioeconómicos y demográficos son de elaboración propia y han sido extraídos usando la [`API del Censo de Estados Unidos`](https://www.census.gov/data/developers/data-sets.html)

# %%
# Cargar datos
all_data = pd.read_csv(f"data/census_data_acs_{CENSUS_YEAR}.csv", header=0, sep=",")

# Renombrar columnas
all_data.rename(columns={"state": "state_code"}, inplace=True)
all_data.rename(columns={"county": "county_code"}, inplace=True)

# Filtrar los datos para excluir el estado 02 (Alaska)
all_data = all_data[all_data["state_code"] != 2]

# Filtrar los datos para excluir el estado 72 (Puerto Rico)
all_data = all_data[all_data["state_code"] != 72]

# Mostrar la tabla
all_data
# Out:
#       state_code  county_code  pop_total_2023  median_age_2023  \
# 0              1            1           59285             39.2
# 1              1            3          239945             43.7
# 2              1            5           24757             40.7
# 3              1            7           22152             41.3
# 4              1            9           59292             40.9
# ...          ...          ...             ...              ...
# 3139          56           37           41786             37.4
# 3140          56           39           23358             40.1
# 3141          56           41           20605             36.7
# 3142          56           43            7708             44.2
# 3143          56           45            6835             43.1
#
#       median_income_2023  households_median_value_2023  \
# 0                  69841                        197900
# 1                  75019                        287000
# 2                  44290                        109900
# 3                  51215                        132600
# 4                  61096                        169700
# ...                  ...                           ...
# 3139               76464                        242900
# 3140              112681                       1371900
# 3141               82672                        255400
# 3142               62648                        188600
# 3143               87545                        214000
#
#       households_avg_size_2023  households_total_2023  \
# 0                         2.61                  22523
# 1                         2.50                  94642
# 2                         2.39                   9080
# 3                         2.74                   7571
# 4                         2.67                  21977
# ...                        ...                    ...
# 3139                      2.45                  16863
# 3140                      2.39                   9383
# 3141                      2.73                   7479
# 3142                      2.21                   3417
# 3143                      2.35                   2754
#
#       households_median_gross_rent_2023  mean_travel_time_2023  ...  \
# 0                                  1200                  25415  ...
# 1                                  1211                  97455  ...
# 2                                   644                   7989  ...
# 3                                   802                   7999  ...
# 4                                   743                  23976  ...
# ...                                 ...                    ...  ...
# 3139                                913                  19567  ...
# 3140                               1758                  12293  ...
# 3141                                882                   8936  ...
# 3142                                725                   3482  ...
# 3143                                694                   2918  ...
#
#       two_more_races_rate_2023  high_school_rate_2023  bachelors_rate_2023  \
# 0                         4.59                  18.70                10.99
# 1                         5.54                  16.15                14.73
# 2                         2.95                  21.48                 4.76
# 3                         2.82                  24.60                 5.06
# 4                         5.15                  19.58                 6.89
# ...                        ...                    ...                  ...
# 3139                      9.26                  15.46                 8.73
# 3140                      6.47                  11.62                31.24
# 3141                      6.18                  18.53                10.02
# 3142                     13.84                  19.30                10.57
# 3143                      9.29                  22.53                 9.93
#
#       poverty_rate_2023  households_renter_rate_2023  \
# 0                 10.58                        25.09
# 1                 10.34                        22.46
# 2                 19.17                        32.51
# 3                 19.22                        22.82
# 4                 13.95                        20.49
# ...                 ...                          ...
# 3139              13.25                        26.02
# 3140               6.99                        38.47
# 3141               7.44                        23.47
# 3142               8.45                        25.81
# 3143               9.77                        11.04
#
#       households_owner_rate_2023  unemployment_rate_2023  \
# 0                          74.91                    2.54
# 1                          77.54                    3.19
# 2                          67.49                    5.71
# 3                          77.18                    9.98
# 4                          79.51                    5.84
# ...                          ...                     ...
# 3139                       73.98                    5.79
# 3140                       61.53                    2.45
# 3141                       76.53                    3.51
# 3142                       74.19                    2.03
# 3143                       88.96                    1.42
#
#       public_transport_rate_2023  no_health_insurance_rate_2023  county_fips
# 0                           0.11                           7.20         1001
# 1                           0.04                           8.06         1003
# 2                           0.07                           9.49         1005
# 3                           0.04                           7.81         1007
# 4                           0.00                          10.11         1009
# ...                          ...                            ...          ...
# 3139                        1.14                          12.85        56037
# 3140                        1.31                          10.00        56039
# 3141                        0.44                          10.85        56041
# 3142                        0.01                          12.22        56043
# 3143                        2.66                          14.07        56045
#
# [3114 rows x 37 columns]

# %% [markdown]
# ### Cargar los resultados electorales

# %% [markdown]
# 📊 Los datos electorales han sido extraídos de la siguiente fuente:
# [`US_County_Level_Election_Results_08-20.csv`](https://github.com/tonmcg/US_County_Level_Election_Results_08-20)

# %%
# Cargar datos
d1 = pd.read_csv(f"data/{ELECTORAL_YEAR}_US_County_Level_Presidential_Results.csv")

# Crear nueva columna 'votes_others'
d1['votes_others'] = d1['total_votes'] - (d1['votes_gop'] + d1['votes_dem'])

# Crear nueva columna 'perc votes_others'
d1['perc votes_others'] = 1 - d1['per_dem'] - d1['per_gop']

# Quedarse con columnas específicas
d1 = d1[['state_name', 'county_fips', 'county_name', 'votes_gop', 'votes_dem', 'total_votes', 'votes_others', 'perc votes_others', 'per_dem', 'per_gop']]

# Renombrar columnas
# d1.columns = ["state", "fips", "county", f"Trump_{ELECTORAL_YEAR}", f"Biden_{ELECTORAL_YEAR}", f"Total_{ELECTORAL_YEAR}", f"Other_{ELECTORAL_YEAR}", f"Perc_Other_{ELECTORAL_YEAR}", f"Perc_Biden_{ELECTORAL_YEAR}", f"Perc_Trump_{ELECTORAL_YEAR}"]
d1.rename(columns={"state_name": "state"}, inplace=True)
d1.rename(columns={"county_name": "county"}, inplace=True)
d1.rename(columns={"votes_gop": f"votes_gop_{ELECTORAL_YEAR}"}, inplace=True)
d1.rename(columns={"votes_dem": f"votes_dem_{ELECTORAL_YEAR}"}, inplace=True)
d1.rename(columns={"total_votes": f"total_votes_{ELECTORAL_YEAR}"}, inplace=True)
d1.rename(columns={"votes_others": f"votes_others_{ELECTORAL_YEAR}"}, inplace=True)
d1.rename(columns={"perc votes_others": f"per_votes_others_{ELECTORAL_YEAR}"}, inplace=True)
d1.rename(columns={"per_dem": f"per_dem_{ELECTORAL_YEAR}"}, inplace=True)
d1.rename(columns={"per_gop": f"per_gop_{ELECTORAL_YEAR}"}, inplace=True)

# Mostrar la tabla
d1
# Out:
#         state  county_fips             county  votes_gop_2024  votes_dem_2024  \
# 0     Alabama         1001     Autauga County           20484            7439
# 1     Alabama         1003     Baldwin County           95798           24934
# 2     Alabama         1005     Barbour County            5606            4158
# 3     Alabama         1007        Bibb County            7572            1619
# 4     Alabama         1009      Blount County           25354            2576
# ...       ...          ...                ...             ...             ...
# 3155  Wyoming        56037  Sweetwater County           12541            3731
# 3156  Wyoming        56039       Teton County            4134            8748
# 3157  Wyoming        56041       Uinta County            7282            1561
# 3158  Wyoming        56043    Washakie County            3125             656
# 3159  Wyoming        56045      Weston County            3069             378
#
#       total_votes_2024  votes_others_2024  per_votes_others_2024  \
# 0                28190                267               0.009471
# 1               121808               1076               0.008834
# 2                 9832                 68               0.006916
# 3                 9241                 50               0.005411
# 4                28115                185               0.006580
# ...                ...                ...                    ...
# 3155             16569                297               0.017925
# 3156             13077                195               0.014912
# 3157              8984                141               0.015695
# 3158              3841                 60               0.015621
# 3159              3494                 47               0.013452
#
#       per_dem_2024  per_gop_2024
# 0         0.263888      0.726641
# 1         0.204699      0.786467
# 2         0.422905      0.570179
# 3         0.175197      0.819392
# 4         0.091624      0.901796
# ...            ...           ...
# 3155      0.225180      0.756895
# 3156      0.668961      0.316128
# 3157      0.173753      0.810552
# 3158      0.170789      0.813590
# 3159      0.108185      0.878363
#
# [3160 rows x 10 columns]

# %% [markdown]
# ### Unir los dos datasets

# %%
# Unir los dos datasets
data_2024 = pd.merge(d1, all_data, how='right', on=["county_fips"])

# Código FIPS tiene que tener 5 dígitos
data_2024['county_fips'] = data_2024['county_fips'].astype(str).str.zfill(5)

# Mostrar la tabla
data_2024
# Out:
#         state county_fips             county  votes_gop_2024  votes_dem_2024  \
# 0     Alabama       01001     Autauga County         20484.0          7439.0
# 1     Alabama       01003     Baldwin County         95798.0         24934.0
# 2     Alabama       01005     Barbour County          5606.0          4158.0
# 3     Alabama       01007        Bibb County          7572.0          1619.0
# 4     Alabama       01009      Blount County         25354.0          2576.0
# ...       ...         ...                ...             ...             ...
# 3109  Wyoming       56037  Sweetwater County         12541.0          3731.0
# 3110  Wyoming       56039       Teton County          4134.0          8748.0
# 3111  Wyoming       56041       Uinta County          7282.0          1561.0
# 3112  Wyoming       56043    Washakie County          3125.0           656.0
# 3113  Wyoming       56045      Weston County          3069.0           378.0
#
#       total_votes_2024  votes_others_2024  per_votes_others_2024  \
# 0              28190.0              267.0               0.009471
# 1             121808.0             1076.0               0.008834
# 2               9832.0               68.0               0.006916
# 3               9241.0               50.0               0.005411
# 4              28115.0              185.0               0.006580
# ...                ...                ...                    ...
# 3109           16569.0              297.0               0.017925
# 3110           13077.0              195.0               0.014912
# 3111            8984.0              141.0               0.015695
# 3112            3841.0               60.0               0.015621
# 3113            3494.0               47.0               0.013452
#
#       per_dem_2024  per_gop_2024  ...  hispanic_rate_2023  \
# 0         0.263888      0.726641  ...                3.69
# 1         0.204699      0.786467  ...                5.58
# 2         0.422905      0.570179  ...                6.02
# 3         0.175197      0.819392  ...                3.36
# 4         0.091624      0.901796  ...               10.06
# ...            ...           ...  ...                 ...
# 3109      0.225180      0.756895  ...               16.57
# 3110      0.668961      0.316128  ...               14.75
# 3111      0.173753      0.810552  ...                9.91
# 3112      0.170789      0.813590  ...               14.10
# 3113      0.108185      0.878363  ...                3.48
#
#       two_more_races_rate_2023  high_school_rate_2023  bachelors_rate_2023  \
# 0                         4.59                  18.70                10.99
# 1                         5.54                  16.15                14.73
# 2                         2.95                  21.48                 4.76
# 3                         2.82                  24.60                 5.06
# 4                         5.15                  19.58                 6.89
# ...                        ...                    ...                  ...
# 3109                      9.26                  15.46                 8.73
# 3110                      6.47                  11.62                31.24
# 3111                      6.18                  18.53                10.02
# 3112                     13.84                  19.30                10.57
# 3113                      9.29                  22.53                 9.93
#
#       poverty_rate_2023  households_renter_rate_2023  \
# 0                 10.58                        25.09
# 1                 10.34                        22.46
# 2                 19.17                        32.51
# 3                 19.22                        22.82
# 4                 13.95                        20.49
# ...                 ...                          ...
# 3109              13.25                        26.02
# 3110               6.99                        38.47
# 3111               7.44                        23.47
# 3112               8.45                        25.81
# 3113               9.77                        11.04
#
#       households_owner_rate_2023  unemployment_rate_2023  \
# 0                          74.91                    2.54
# 1                          77.54                    3.19
# 2                          67.49                    5.71
# 3                          77.18                    9.98
# 4                          79.51                    5.84
# ...                          ...                     ...
# 3109                       73.98                    5.79
# 3110                       61.53                    2.45
# 3111                       76.53                    3.51
# 3112                       74.19                    2.03
# 3113                       88.96                    1.42
#
#       public_transport_rate_2023  no_health_insurance_rate_2023
# 0                           0.11                           7.20
# 1                           0.04                           8.06
# 2                           0.07                           9.49
# 3                           0.04                           7.81
# 4                           0.00                          10.11
# ...                          ...                            ...
# 3109                        1.14                          12.85
# 3110                        1.31                          10.00
# 3111                        0.44                          10.85
# 3112                        0.01                          12.22
# 3113                        2.66                          14.07
#
# [3114 rows x 46 columns]

# %% [markdown]
# ### Incluir cambios en los condados de Connecticut (efectivos en 2024)
# https://appliedgeographic.com/2023/04/changing-of-the-counties/

# %%
# Eliminar condado que no está en el dataset de datos del censo de 2016 y 2019
data_2024 = data_2024[data_2024['county_fips'] != "09190"]
data_2024[data_2024['state'] == "Connecticut"]
# Out:
#            state county_fips                                          county  \
# 279  Connecticut       09110                         Capitol Planning Region
# 280  Connecticut       09120              Greater Bridgeport Planning Region
# 281  Connecticut       09130  Lower Connecticut River Valley Planning Region
# 282  Connecticut       09140                Naugatuck Valley Planning Region
# 283  Connecticut       09150        Northeastern Connecticut Planning Region
# 284  Connecticut       09160                 Northwest Hills Planning Region
# 285  Connecticut       09170       South Central Connecticut Planning Region
# 286  Connecticut       09180        Southeastern Connecticut Planning Region
#
#      votes_gop_2024  votes_dem_2024  total_votes_2024  votes_others_2024  \
# 279        181038.0        285105.0          474268.0             8125.0
# 280         51519.0         83461.0          137015.0             2035.0
# 281         44318.0         58360.0          104480.0             1802.0
# 282        115290.0         99237.0          217520.0             2993.0
# 283         29028.0         21165.0           50962.0              769.0
# 284         31944.0         31137.0           64076.0              995.0
# 285        103087.0        156248.0          264854.0             5519.0
# 286         58392.0         76146.0          136954.0             2416.0
#
#      per_votes_others_2024  per_dem_2024  per_gop_2024  ...  \
# 279               0.017132      0.601147      0.381721  ...
# 280               0.014852      0.609138      0.376010  ...
# 281               0.017247      0.558576      0.424177  ...
# 282               0.013760      0.456220      0.530020  ...
# 283               0.015090      0.415309      0.569601  ...
# 284               0.015528      0.485939      0.498533  ...
# 285               0.020838      0.589940      0.389222  ...
# 286               0.017641      0.555997      0.426362  ...
#
#      hispanic_rate_2023  two_more_races_rate_2023  high_school_rate_2023  \
# 279               17.38                      8.93                  15.24
# 280               26.06                      9.82                  14.47
# 281                7.45                      7.41                  16.34
# 282               19.19                     10.97                  18.13
# 283                5.05                      6.08                  22.52
# 284                8.37                      6.88                  18.25
# 285               19.10                      9.04                  17.55
# 286               14.67                      9.26                  17.54
#
#      bachelors_rate_2023  poverty_rate_2023  households_renter_rate_2023  \
# 279                15.96               9.96                        34.61
# 280                15.98              12.90                        34.62
# 281                18.75               6.64                        24.77
# 282                13.51              10.21                        32.36
# 283                11.04               8.49                        23.80
# 284                16.96               9.06                        24.14
# 285                14.88              11.20                        39.44
# 286                13.58              10.15                        34.61
#
#      households_owner_rate_2023  unemployment_rate_2023  \
# 279                       65.39                    5.26
# 280                       65.38                    7.43
# 281                       75.23                    3.88
# 282                       67.64                    6.10
# 283                       76.20                    6.23
# 284                       75.86                    5.43
# 285                       60.56                    5.91
# 286                       65.39                    5.07
#
#      public_transport_rate_2023  no_health_insurance_rate_2023
# 279                        1.31                           4.16
# 280                        2.94                           8.33
# 281                        0.62                           3.38
# 282                        0.72                           4.42
# 283                        0.07                           3.69
# 284                        0.63                           3.87
# 285                        1.54                           5.09
# 286                        0.64                           4.37
#
# [8 rows x 46 columns]

# %% [markdown]
# ### Calcular el ganador en cada condado

# %% [markdown]
# <div style="border-left: 4px solid #0074cc; background-color: #e6f4ff; padding: 10px;">
#     <strong>Nota:</strong> Por simplicidad, para calcular el ganador en cada condado asumimos que si hay un empate el ganador es Biden. En cualquier otro caso, el ganador será el que haya obtenido más del 50% de los votos.
# </div>

# %%
data_2024[f'winner_{ELECTORAL_YEAR}'] = data_2024[f'per_dem_{ELECTORAL_YEAR}'].apply(lambda x: "dem" if x >= 0.50 else "gop")
# Out:
# /var/folders/dh/_ks73kfn57l67vxm7b5y16qw0000gn/T/ipykernel_5263/2758343973.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_2024[f'winner_{ELECTORAL_YEAR}'] = data_2024[f'per_dem_{ELECTORAL_YEAR}'].apply(lambda x: "dem" if x >= 0.50 else "gop")

# %% [markdown]
# ### Valores ausentes (NAs)

# %%
missing_fips_2024 = data_2024[data_2024.isna().any(axis=1)]['county_fips'].tolist()
missing_fips_2024
# Out:
# ['15005']

# %%
data_2024 = data_2024.dropna(how="any")
data_2024[data_2024.isna().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [state, county_fips, county, votes_gop_2024, votes_dem_2024, total_votes_2024, votes_others_2024, per_votes_others_2024, per_dem_2024, per_gop_2024, state_code, county_code, pop_total_2023, median_age_2023, median_income_2023, households_median_value_2023, households_avg_size_2023, households_total_2023, households_median_gross_rent_2023, mean_travel_time_2023, pop_total_male_rate_2023, pop_total_female_rate_2023, pop_18_39_male_rate_2023, pop_18_39_female_rate_2023, pop_40_64_male_rate_2023, pop_40_64_female_rate_2023, pop_over_65_male_rate_2023, pop_over_65_female_rate_2023, veterans_rate_2023, inmigrants_rate_2023, white_rate_2023, black_rate_2023, native_rate_2023, asian_rate_2023, pacific_rate_2023, other_rate_2023, hispanic_rate_2023, two_more_races_rate_2023, high_school_rate_2023, bachelors_rate_2023, poverty_rate_2023, households_renter_rate_2023, households_owner_rate_2023, unemployment_rate_2023, public_transport_rate_2023, no_health_insurance_rate_2023, winner_2024]
# Index: []
#
# [0 rows x 47 columns]

# %% [markdown]
# ### Añadir columnas de delta (2024 - 2020)

# %%
# Seleccionar las columnas de delta de 2024
delta_cols_2024 = ["county_fips", "delta_per_dem_2024", "delta_per_gop_2024", "delta_per_oth_2024"]

# Unir los datos por "county_fips"
data_2024 = data_2024.merge(merged_data[delta_cols_2024], on="county_fips", how="left")

# %%
# Identificar los county_fips con valores NaN
missing_fips = data_2024[data_2024["delta_per_dem_2024"].isna()]["county_fips"].iloc[0]
print(missing_fips)

missing_fips_2024.append(missing_fips)
print(missing_fips_2024)
# Out:
# 09110
# ['15005', '09110']

# %% [markdown]
# ### Quitar "_2024" del nombre de las variables

# %%
# Renombrar columnas para quitar el sufijo "_{CENSUS_YEAR}" o "_{ELECTORAL_YEAR}"
data_2024.columns = [col.replace(f'_{CENSUS_YEAR}', '').replace(f'_{ELECTORAL_YEAR}', '') for col in data_2024.columns]

# %% [markdown]
# ## Guardar datos

# %%
fips_to_remove = missing_fips_2016 + missing_fips_2020 + missing_fips_2024

data_2016 = data_2016[~data_2016['county_fips'].isin(fips_to_remove)]
data_2020 = data_2020[~data_2020['county_fips'].isin(fips_to_remove)]
data_2024 = data_2024[~data_2024['county_fips'].isin(fips_to_remove)]

# %%
# Cargar el diccionario desde el archivo JSON
import json

with open('data/code_to_state.json', 'r') as file:
    code_to_state = json.load(file)

# Usar el diccionario invertido para mapear los códigos a nombres en la columna "state"
data_2016['state'] = data_2016['state'].map(code_to_state)

# Guardar el DataFrame en un archivo CSV
data_2016.to_csv("data/final_data_2016.csv", index=False)

# Mostrar la tabla resultante
data_2016
# Out:
# /var/folders/dh/_ks73kfn57l67vxm7b5y16qw0000gn/T/ipykernel_5263/1962086240.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_2016['state'] = data_2016['state'].map(code_to_state)
#         state county_fips             county  votes_gop  votes_dem  \
# 0     Alabama       01001     Autauga County    18110.0     5908.0
# 1     Alabama       01003     Baldwin County    72780.0    18409.0
# 2     Alabama       01005     Barbour County     5431.0     4848.0
# 3     Alabama       01007        Bibb County     6733.0     1874.0
# 4     Alabama       01009      Blount County    22808.0     2150.0
# ...       ...         ...                ...        ...        ...
# 3103  Wyoming       56037  Sweetwater County    12153.0     3233.0
# 3104  Wyoming       56039       Teton County     3920.0     7313.0
# 3105  Wyoming       56041       Uinta County     6154.0     1202.0
# 3106  Wyoming       56043    Washakie County     2911.0      532.0
# 3107  Wyoming       56045      Weston County     2898.0      294.0
#
#       total_votes  votes_others  per_votes_others   per_dem   per_gop  ...  \
# 0         24661.0         643.0          0.026074  0.239569  0.734358  ...
# 1         94090.0        2901.0          0.030832  0.195653  0.773515  ...
# 2         10390.0         111.0          0.010683  0.466603  0.522714  ...
# 3          8748.0         141.0          0.016118  0.214220  0.769662  ...
# 4         25384.0         426.0          0.016782  0.084699  0.898519  ...
# ...           ...           ...               ...       ...       ...  ...
# 3103      16661.0        1275.0          0.076526  0.194046  0.729428  ...
# 3104      12176.0         943.0          0.077447  0.600608  0.321945  ...
# 3105       8053.0         697.0          0.086552  0.149261  0.764187  ...
# 3106       3715.0         272.0          0.073217  0.143203  0.783580  ...
# 3107       3334.0         142.0          0.042591  0.088182  0.869226  ...
#
#       poverty_rate  households_renter_rate  households_owner_rate  \
# 0            12.78                   26.08                  73.92
# 1            13.22                   28.48                  71.52
# 2            23.84                   36.41                  63.59
# 3            15.43                   24.89                  75.11
# 4            16.55                   21.10                  78.90
# ...            ...                     ...                    ...
# 3103         11.30                   29.01                  70.99
# 3104          7.34                   39.50                  60.50
# 3105         13.59                   26.95                  73.05
# 3106         13.54                   26.25                  73.75
# 3107         13.39                   21.97                  78.03
#
#       unemployment_rate  public_transport_rate  no_health_insurance_rate  \
# 0                  7.64                   0.04                      9.97
# 1                  7.50                   0.06                     12.81
# 2                 17.65                   0.13                     13.86
# 3                  8.31                   0.19                      8.88
# 4                  7.67                   0.15                     11.54
# ...                 ...                    ...                       ...
# 3103               5.41                   1.21                     13.40
# 3104               2.61                   4.87                     16.81
# 3105               4.40                   1.29                     13.93
# 3106               6.80                   0.01                     16.60
# 3107               5.16                   4.94                     10.74
#
#       winner  delta_per_dem  delta_per_gop  delta_per_oth
# 0        gop      -2.618911       0.802053       1.816858
# 1        gop      -2.001264      -0.038277       2.039541
# 2        gop      -4.592041       3.933864       0.658177
# 3        gop      -4.796528       3.899783       0.896745
# 4        gop      -3.877888       3.358964       0.518923
# ...      ...            ...            ...            ...
# 3103     gop      -9.090925       4.721905       4.369020
# 3104     dem       5.367221     -10.584667       5.217445
# 3105     gop      -4.333320      -1.813854       6.147174
# 3106     gop      -5.981390       1.318888       4.662502
# 3107     gop      -3.881132       2.029447       1.851685
#
# [3107 rows x 50 columns]

# %%
# Guardar el dataframe en un archivo CSV
data_2020.to_csv(f"data/final_data_{2020}.csv", index=False)

# Mostrar la tabla
data_2020
# Out:
#         state county_fips             county  votes_gop  votes_dem  \
# 0     Alabama       01001     Autauga County    19838.0     7503.0
# 1     Alabama       01003     Baldwin County    83544.0    24578.0
# 2     Alabama       01005     Barbour County     5622.0     4816.0
# 3     Alabama       01007        Bibb County     7525.0     1986.0
# 4     Alabama       01009      Blount County    24711.0     2640.0
# ...       ...         ...                ...        ...        ...
# 3107  Wyoming       56037  Sweetwater County    12229.0     3823.0
# 3108  Wyoming       56039       Teton County     4341.0     9848.0
# 3109  Wyoming       56041       Uinta County     7496.0     1591.0
# 3110  Wyoming       56043    Washakie County     3245.0      651.0
# 3111  Wyoming       56045      Weston County     3107.0      360.0
#
#       total_votes  votes_others  per_votes_others   per_dem   per_gop  ...  \
# 0         27770.0         429.0          0.015448  0.270184  0.714368  ...
# 1        109679.0        1557.0          0.014196  0.224090  0.761714  ...
# 2         10518.0          80.0          0.007606  0.457882  0.534512  ...
# 3          9595.0          84.0          0.008755  0.206983  0.784263  ...
# 4         27588.0         237.0          0.008591  0.095694  0.895716  ...
# ...           ...           ...               ...       ...       ...  ...
# 3107      16603.0         551.0          0.033187  0.230260  0.736554  ...
# 3108      14677.0         488.0          0.033249  0.670982  0.295769  ...
# 3109       9402.0         315.0          0.033504  0.169219  0.797277  ...
# 3110       4012.0         116.0          0.028913  0.162263  0.808824  ...
# 3111       3542.0          75.0          0.021174  0.101637  0.877188  ...
#
#       poverty_rate  households_renter_rate  households_owner_rate  \
# 0            15.06                   26.71                  73.29
# 1            10.20                   24.75                  75.25
# 2            27.11                   39.10                  60.90
# 3            16.63                   25.58                  74.42
# 4            13.42                   21.22                  78.78
# ...            ...                     ...                    ...
# 3107         11.31                   23.78                  76.22
# 3108          6.13                   39.59                  60.41
# 3109         11.22                   22.94                  77.06
# 3110         10.28                   23.51                  76.49
# 3111         13.78                   16.98                  83.02
#
#       unemployment_rate  public_transport_rate  no_health_insurance_rate  \
# 0                  3.68                   0.29                      6.96
# 1                  4.26                   0.02                      8.78
# 2                  9.17                   0.11                     10.03
# 3                  7.28                   0.00                      9.79
# 4                  3.36                   0.05                     10.68
# ...                 ...                    ...                       ...
# 3107               6.09                   1.41                     11.18
# 3108               1.08                   2.12                     12.71
# 3109               6.28                   1.47                     11.09
# 3110               3.92                   0.00                     14.73
# 3111               4.14                   4.26                     11.26
#
#       winner  delta_per_dem  delta_per_gop  delta_per_oth
# 0        gop       3.061510      -1.998987      -1.062523
# 1        gop       2.843720      -1.180099      -1.663621
# 2        gop      -0.872078       1.179812      -0.307734
# 3        gop      -0.723759       1.460100      -0.736341
# 4        gop       1.099476      -0.280322      -0.819153
# ...      ...            ...            ...            ...
# 3107     gop       3.621362       0.712563      -4.333925
# 3108     dem       7.037406      -2.617592      -4.419814
# 3109     gop       1.995817       3.308992      -5.304809
# 3110     gop       1.905998       2.524345      -4.430343
# 3111     gop       1.345513       0.796187      -2.141700
#
# [3107 rows x 50 columns]

# %%
# Guardar el dataframe en un archivo CSV
data_2024.to_csv(f"data/final_data_{2024}.csv", index=False)

# Mostrar la tabla
data_2024
# Out:
#         state county_fips             county  votes_gop  votes_dem  \
# 0     Alabama       01001     Autauga County    20484.0     7439.0
# 1     Alabama       01003     Baldwin County    95798.0    24934.0
# 2     Alabama       01005     Barbour County     5606.0     4158.0
# 3     Alabama       01007        Bibb County     7572.0     1619.0
# 4     Alabama       01009      Blount County    25354.0     2576.0
# ...       ...         ...                ...        ...        ...
# 3107  Wyoming       56037  Sweetwater County    12541.0     3731.0
# 3108  Wyoming       56039       Teton County     4134.0     8748.0
# 3109  Wyoming       56041       Uinta County     7282.0     1561.0
# 3110  Wyoming       56043    Washakie County     3125.0      656.0
# 3111  Wyoming       56045      Weston County     3069.0      378.0
#
#       total_votes  votes_others  per_votes_others   per_dem   per_gop  ...  \
# 0         28190.0         267.0          0.009471  0.263888  0.726641  ...
# 1        121808.0        1076.0          0.008834  0.204699  0.786467  ...
# 2          9832.0          68.0          0.006916  0.422905  0.570179  ...
# 3          9241.0          50.0          0.005411  0.175197  0.819392  ...
# 4         28115.0         185.0          0.006580  0.091624  0.901796  ...
# ...           ...           ...               ...       ...       ...  ...
# 3107      16569.0         297.0          0.017925  0.225180  0.756895  ...
# 3108      13077.0         195.0          0.014912  0.668961  0.316128  ...
# 3109       8984.0         141.0          0.015695  0.173753  0.810552  ...
# 3110       3841.0          60.0          0.015621  0.170789  0.813590  ...
# 3111       3494.0          47.0          0.013452  0.108185  0.878363  ...
#
#       poverty_rate  households_renter_rate  households_owner_rate  \
# 0            10.58                   25.09                  74.91
# 1            10.34                   22.46                  77.54
# 2            19.17                   32.51                  67.49
# 3            19.22                   22.82                  77.18
# 4            13.95                   20.49                  79.51
# ...            ...                     ...                    ...
# 3107         13.25                   26.02                  73.98
# 3108          6.99                   38.47                  61.53
# 3109          7.44                   23.47                  76.53
# 3110          8.45                   25.81                  74.19
# 3111          9.77                   11.04                  88.96
#
#       unemployment_rate  public_transport_rate  no_health_insurance_rate  \
# 0                  2.54                   0.11                      7.20
# 1                  3.19                   0.04                      8.06
# 2                  5.71                   0.07                      9.49
# 3                  9.98                   0.04                      7.81
# 4                  5.84                   0.00                     10.11
# ...                 ...                    ...                       ...
# 3107               5.79                   1.14                     12.85
# 3108               2.45                   1.31                     10.00
# 3109               3.51                   0.44                     10.85
# 3110               2.03                   0.01                     12.22
# 3111               1.42                   2.66                     14.07
#
#       winner  delta_per_dem  delta_per_gop  delta_per_oth
# 0        gop      -0.629575       1.227263      -0.597688
# 1        gop      -1.939110       2.475350      -0.536240
# 2        gop      -3.497693       3.566674      -0.068982
# 3        gop      -3.178531       3.512920      -0.334389
# 4        gop      -0.407009       0.608067      -0.201057
# ...      ...            ...            ...            ...
# 3107     gop      -0.508004       2.034177      -1.526173
# 3108     dem      -0.202104       2.035866      -1.833762
# 3109     gop       0.453402       1.327492      -1.780894
# 3110     gop       0.852565       0.476668      -1.329233
# 3111     gop       0.654797       0.117488      -0.772285
#
# [3107 rows x 50 columns]

# %%
# Encontrar los `county_fips` comunes en los tres conjuntos de datos
common_fips = set(data_2016["county_fips"]).intersection(data_2020["county_fips"]).intersection(data_2024["county_fips"])
len(common_fips)
# Out:
# 3107

# %%
# Guardamos las variables en vectores para uso futuro
state_names = data_2024['state']
fips_codes = data_2024['county_fips']
county_names = data_2024['county']

# Crear df para guardarlos
df_vectors = pd.DataFrame({
    'state': state_names,
    'fips': fips_codes,
    'county': county_names
})

# Guardar en archivo CSV
df_vectors.to_csv('data/state_fips_county.csv', index=False)
